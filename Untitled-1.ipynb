# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Provide the correct file path to the Excel file using raw string literal (r prefix)
path = r"C:\Users\juani\Desktop\analitica1\Proyecto\Proyecto2\data.xls"

# Read the Excel file
data_df = pd.read_excel(path)

# Display the first few rows of the DataFrame
data_df.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
# ...

# %%
column_names = ["ID", "LIMIT_BAL", "SEX", "EDUCATION", "MARRIAGE", "AGE", "PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6", "BILL_AMT1", "BILL_AMT2", "BILL_AMT3", "BILL_AMT4", "BILL_AMT5", "BILL_AMT6", "PAY_AMT1", "PAY_AMT2", "PAY_AMT3", "PAY_AMT4", "PAY_AMT5", "PAY_AMT6", "default payment next month"]

# Asignar los nombres de las columnas al DataFrame
data_df.columns = column_names

# Mostrar las primeras filas del DataFrame
data_df.head()

# Quitar la primera fila del DataFrame
data_df = data_df.drop(index=0)

# Mostrar las primeras filas del DataFrame actualizado
data_df.head()
# Out:
#   ID LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  ...  \
# 1  1     20000   2         2        1  24     2     2    -1    -1  ...
# 2  2    120000   2         2        2  26    -1     2     0     0  ...
# 3  3     90000   2         2        2  34     0     0     0     0  ...
# 4  4     50000   2         2        1  37     0     0     0     0  ...
# 5  5     50000   1         2        1  57    -1     0    -1     0  ...
#
#   BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4 PAY_AMT5  \
# 1         0         0         0        0      689        0        0        0
# 2      3272      3455      3261        0     1000     1000     1000        0
# 3     14331     14948     15549     1518     1500     1000     1000     1000
# 4     28314     28959     29547     2000     2019     1200     1100     1069
# 5     20940     19146     19131     2000    36681    10000     9000      689
#
#   PAY_AMT6 default payment next month
# ...

# %%
data_df.dtypes
# Out:
# ID                            object
# LIMIT_BAL                     object
# SEX                           object
# EDUCATION                     object
# MARRIAGE                      object
# AGE                           object
# PAY_0                         object
# PAY_2                         object
# PAY_3                         object
# PAY_4                         object
# PAY_5                         object
# PAY_6                         object
# BILL_AMT1                     object
# BILL_AMT2                     object
# BILL_AMT3                     object
# BILL_AMT4                     object
# BILL_AMT5                     object
# BILL_AMT6                     object
# PAY_AMT1                      object
# PAY_AMT2                      object
# PAY_AMT3                      object
# PAY_AMT4                      object
# PAY_AMT5                      object
# PAY_AMT6                      object
# default payment next month    object
# dtype: object

# %%
data_df = data_df.apply(pd.to_numeric, errors='coerce')

# Mostrar los tipos de datos después de la conversión
print(data_df.dtypes)
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
#Análisis de completitud
(data_df.isnull().sum() / data_df.shape[0]).sort_values(ascending = False)
# Out:
# ID                            0.0
# BILL_AMT2                     0.0
# PAY_AMT6                      0.0
# PAY_AMT5                      0.0
# PAY_AMT4                      0.0
# PAY_AMT3                      0.0
# PAY_AMT2                      0.0
# PAY_AMT1                      0.0
# BILL_AMT6                     0.0
# BILL_AMT5                     0.0
# BILL_AMT4                     0.0
# BILL_AMT3                     0.0
# BILL_AMT1                     0.0
# LIMIT_BAL                     0.0
# PAY_6                         0.0
# PAY_5                         0.0
# PAY_4                         0.0
# PAY_3                         0.0
# PAY_2                         0.0
# PAY_0                         0.0
# AGE                           0.0
# MARRIAGE                      0.0
# EDUCATION                     0.0
# SEX                           0.0
# default payment next month    0.0
# dtype: float64

# %%
# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Gráfico de violín
sns.violinplot(x="SEX", data=data_df, ax=ax1)
ax1.set_xlabel("SEX")
ax1.set_ylabel("Distribución")
ax1.set_title("Distribución de la variable SEX")

# Gráfico de conteo
sns.countplot(x="SEX", data=data_df, ax=ax2)
ax2.set_xlabel("SEX")
ax2.set_ylabel("Cantidad de datos")
ax2.set_title("Cantidad de datos por nivel de SEX")

# Ajustar el diseño
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %%
# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Gráfico de violín
sns.violinplot(x="EDUCATION", data=data_df, ax=ax1)
ax1.set_xlabel("Educación")
ax1.set_ylabel("Distribución")
ax1.set_title("Distribución de la variable EDUCATION")

# Gráfico de conteo
sns.countplot(x="EDUCATION", data=data_df, ax=ax2)
ax2.set_xlabel("Educación")
ax2.set_ylabel("Cantidad de datos")
ax2.set_title("Cantidad de datos por nivel de educación")

# Ajustar el diseño
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %%
# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Gráfico de violín
sns.violinplot(x="MARRIAGE", data=data_df, ax=ax1)
ax1.set_xlabel("Matrimonio")
ax1.set_ylabel("Distribución")
ax1.set_title("Distribución de la variable MARRIAGE")

# Gráfico de conteo
sns.countplot(x="MARRIAGE", data=data_df, ax=ax2)
ax2.set_xlabel("Matrimonio")
ax2.set_ylabel("Cantidad de datos")
ax2.set_title("Cantidad de datos por estado civil")

# Ajustar el diseño
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %%
# Copiar el DataFrame original data_df
data_df_modeling = data_df.copy()

# Obtener variables categóricas
variables_categoricas = ['MARRIAGE', 'EDUCATION', 'SEX']

# Convertir variables categóricas en variables dummy y agregarlas al DataFrame copiado
for variable in variables_categoricas:
    dummies = pd.get_dummies(data_df_modeling[variable], prefix=variable, drop_first=True)
    data_df_modeling = pd.concat([data_df_modeling, dummies], axis=1)
    data_df_modeling.drop(variable, axis=1, inplace=True)

# Ver las primeras filas del DataFrame copiado con las variables dummy
data_df_modeling.head()
# Out:
#    ID  LIMIT_BAL  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
# 1   1      20000   24      2      2     -1     -1     -2     -2       3913
# 2   2     120000   26     -1      2      0      0      0      2       2682
# 3   3      90000   34      0      0      0      0      0      0      29239
# 4   4      50000   37      0      0      0      0      0      0      46990
# 5   5      50000   57     -1      0     -1      0      0      0       8617
#
#    ...  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3  EDUCATION_1  EDUCATION_2  \
# 1  ...        True       False       False        False         True
# 2  ...       False        True       False        False         True
# 3  ...       False        True       False        False         True
# 4  ...        True       False       False        False         True
# 5  ...        True       False       False        False         True
#
#    EDUCATION_3  EDUCATION_4  EDUCATION_5  EDUCATION_6  SEX_2
# ...

# %%
data_df_modeling.to_csv('clean_data.txt')

# %% [markdown]
# Exploración de datos

# %% [markdown]
# EXPLORACIÓN CATEGORICOS

# %%
import seaborn as sns

# Crear una tabla pivote para contar los valores de sexo para cada valor de default payment next month
pivot_table = data_df.pivot_table(index='SEX', columns='default payment next month', aggfunc='size')

# Crear el mapa de calor
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, fmt='g', cmap='coolwarm')
plt.xlabel('default payment next month')
plt.ylabel('SEX')
plt.title('Distribución del pago por defecto por sexo')
plt.show()

# %%
# Crear una tabla pivote para contar los valores de educación para cada valor de default payment next month
pivot_table_education = data_df.pivot_table(index='EDUCATION', columns='default payment next month', aggfunc='size')

# Crear el mapa de calor
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table_education, annot=True, fmt='g', cmap='coolwarm')
plt.xlabel('default payment next month')
plt.ylabel('EDUCATION')
plt.title('Distribución del pago por defecto por nivel de educación')
plt.show()

# %%
# Crear una tabla pivote para contar los valores de estado civil para cada valor de default payment next month
pivot_table_marriage = data_df.pivot_table(index='MARRIAGE', columns='default payment next month', aggfunc='size')

# Crear el mapa de calor
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table_marriage, annot=True, fmt='g', cmap='coolwarm')
plt.xlabel('default payment next month')
plt.ylabel('MARRIAGE')
plt.title('Distribución del pago por defecto por estado civil')
plt.show()

# %% [markdown]
# No categoricas

# %%
# Descripción de la variable 'AGE'
age_description = data_df['AGE'].describe()
print(age_description)

# Histograma y Boxplot de la variable 'AGE'
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(data_df['AGE'], color='skyblue', edgecolor='black')
plt.title('Histograma de la variable "AGE"')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.grid(True)

plt.subplot(1, 2, 2)
sns.boxplot(x='default payment next month', y='AGE', data=data_df)
plt.xlabel('default payment next month')
plt.ylabel('Edad')
plt.title('Diagrama de Caja de la variable "AGE" con respecto a la variable de respuesta')
plt.grid(True)

plt.show()

# Calcular el porcentaje de valores atípicos en AGE
Q1, Q3 = data_df['AGE'].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_percentage = ((data_df['AGE'] < lower_bound) | (data_df['AGE'] > upper_bound)).mean() * 100

print("Porcentaje de valores atípicos en AGE:", outliers_percentage, "%")
# Out:
# count    30000.000000
# mean        35.485500
# std          9.217904
# min         21.000000
# 25%         28.000000
# 50%         34.000000
# 75%         41.000000
# max         79.000000
# Name: AGE, dtype: float64
# Porcentaje de valores atípicos en AGE: 0.9066666666666667 %

# %%
# Descripción de la variable 'PAY_0'
pay_0_description = data_df['PAY_0'].describe()
print(pay_0_description)

# Histograma y Boxplot de la variable 'PAY_0'
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(data_df['PAY_0'], color='skyblue', edgecolor='black')
plt.title('Histograma de la variable "PAY_0"')
plt.xlabel('Estado de Pago en el Mes Anterior (PAY_0)')
plt.ylabel('Frecuencia')
plt.grid(True)

plt.subplot(1, 2, 2)
sns.boxplot(x='default payment next month', y='PAY_0', data=data_df)
plt.xlabel('default payment next month')
plt.ylabel('Estado de Pago en el Mes Anterior (PAY_0)')
plt.title('Diagrama de Caja de la variable "PAY_0" con respecto a la variable de respuesta')
plt.grid(True)

plt.show()

# Calcular el porcentaje de valores atípicos en PAY_0
Q1, Q3 = data_df['PAY_0'].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_percentage = ((data_df['PAY_0'] < lower_bound) | (data_df['PAY_0'] > upper_bound)).mean() * 100

print("Porcentaje de valores atípicos en PAY_0:", outliers_percentage, "%")
# Out:
# count    30000.000000
# mean        -0.016700
# std          1.123802
# min         -2.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          0.000000
# max          8.000000
# Name: PAY_0, dtype: float64
# Porcentaje de valores atípicos en PAY_0: 10.433333333333334 %

# %%
# Descripción de la variable 'PAY_2'
pay_2_description = data_df['PAY_2'].describe()
print(pay_2_description)

# Histograma y Boxplot de la variable 'PAY_2'
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(data_df['PAY_2'], color='skyblue', edgecolor='black')
plt.title('Histograma de la variable "PAY_2"')
plt.xlabel('Estado de Pago en el Segundo Mes Anterior (PAY_2)')
plt.ylabel('Frecuencia')
plt.grid(True)

plt.subplot(1, 2, 2)
sns.boxplot(x='default payment next month', y='PAY_2', data=data_df)
plt.xlabel('default payment next month')
plt.ylabel('Estado de Pago en el Segundo Mes Anterior (PAY_2)')
plt.title('Diagrama de Caja de la variable "PAY_2" con respecto a la variable de respuesta')
plt.grid(True)

plt.show()

# Calcular el porcentaje de valores atípicos en PAY_2
Q1, Q3 = data_df['PAY_2'].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_percentage = ((data_df['PAY_2'] < lower_bound) | (data_df['PAY_2'] > upper_bound)).mean() * 100

print("Porcentaje de valores atípicos en PAY_2:", outliers_percentage, "%")
# Out:
# count    30000.000000
# mean        -0.133767
# std          1.197186
# min         -2.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          0.000000
# max          8.000000
# Name: PAY_2, dtype: float64
# Porcentaje de valores atípicos en PAY_2: 14.7 %

# %%
# Descripción de la variable 'PAY_3'
pay_3_description = data_df['PAY_3'].describe()
print(pay_3_description)

# Histograma y Boxplot de la variable 'PAY_3'
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(data_df['PAY_3'], color='skyblue', edgecolor='black')
plt.title('Histograma de la variable "PAY_3"')
plt.xlabel('Estado de Pago en el Tercer Mes Anterior (PAY_3)')
plt.ylabel('Frecuencia')
plt.grid(True)

plt.subplot(1, 2, 2)
sns.boxplot(x='default payment next month', y='PAY_3', data=data_df)
plt.xlabel('default payment next month')
plt.ylabel('Estado de Pago en el Tercer Mes Anterior (PAY_3)')
plt.title('Diagrama de Caja de la variable "PAY_3" con respecto a la variable de respuesta')
plt.grid(True)

plt.show()

# Calcular el porcentaje de valores atípicos en PAY_3
Q1, Q3 = data_df['PAY_3'].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_percentage = ((data_df['PAY_3'] < lower_bound) | (data_df['PAY_3'] > upper_bound)).mean() * 100

print("Porcentaje de valores atípicos en PAY_3:", outliers_percentage, "%")
# Out:
# count    30000.000000
# mean        -0.166200
# std          1.196868
# min         -2.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          0.000000
# max          8.000000
# Name: PAY_3, dtype: float64
# Porcentaje de valores atípicos en PAY_3: 14.030000000000001 %

# %%
# Descripción de la variable 'PAY_4'
pay_4_description = data_df['PAY_4'].describe()
print(pay_4_description)

# Histograma y Boxplot de la variable 'PAY_4'
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(data_df['PAY_4'], color='skyblue', edgecolor='black')
plt.title('Histograma de la variable "PAY_4"')
plt.xlabel('Estado de Pago en el Cuarto Mes Anterior (PAY_4)')
plt.ylabel('Frecuencia')
plt.grid(True)

plt.subplot(1, 2, 2)
sns.boxplot(x='default payment next month', y='PAY_4', data=data_df)
plt.xlabel('default payment next month')
plt.ylabel('Estado de Pago en el Cuarto Mes Anterior (PAY_4)')
plt.title('Diagrama de Caja de la variable "PAY_4" con respecto a la variable de respuesta')
plt.grid(True)

plt.show()

# Calcular el porcentaje de valores atípicos en PAY_4
Q1, Q3 = data_df['PAY_4'].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_percentage = ((data_df['PAY_4'] < lower_bound) | (data_df['PAY_4'] > upper_bound)).mean() * 100

print("Porcentaje de valores atípicos en PAY_4:", outliers_percentage, "%")
# Out:
# count    30000.000000
# mean        -0.220667
# std          1.169139
# min         -2.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          0.000000
# max          8.000000
# Name: PAY_4, dtype: float64
# Porcentaje de valores atípicos en PAY_4: 11.693333333333333 %

# %%
# Descripción de la variable 'PAY_5'
pay_5_description = data_df['PAY_5'].describe()
print(pay_5_description)

# Histograma y Boxplot de la variable 'PAY_5'
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(data_df['PAY_5'], color='skyblue', edgecolor='black')
plt.title('Histograma de la variable "PAY_5"')
plt.xlabel('Estado de Pago en el Quinto Mes Anterior (PAY_5)')
plt.ylabel('Frecuencia')
plt.grid(True)

plt.subplot(1, 2, 2)
sns.boxplot(x='default payment next month', y='PAY_5', data=data_df)
plt.xlabel('default payment next month')
plt.ylabel('Estado de Pago en el Quinto Mes Anterior (PAY_5)')
plt.title('Diagrama de Caja de la variable "PAY_5" con respecto a la variable de respuesta')
plt.grid(True)

plt.show()

# Calcular el porcentaje de valores atípicos en PAY_5
Q1, Q3 = data_df['PAY_5'].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_percentage = ((data_df['PAY_5'] < lower_bound) | (data_df['PAY_5'] > upper_bound)).mean() * 100

print("Porcentaje de valores atípicos en PAY_5:", outliers_percentage, "%")
# Out:
# count    30000.000000
# mean        -0.266200
# std          1.133187
# min         -2.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          0.000000
# max          8.000000
# Name: PAY_5, dtype: float64
# Porcentaje de valores atípicos en PAY_5: 9.893333333333333 %

# %%
# Descripción de la variable 'PAY_6'
pay_6_description = data_df['PAY_6'].describe()
print(pay_6_description)

# Histograma y Boxplot de la variable 'PAY_6'
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.hist(data_df['PAY_6'], color='skyblue', edgecolor='black')
plt.title('Histograma de la variable "PAY_6"')
plt.xlabel('Estado de Pago en el Sexto Mes Anterior (PAY_6)')
plt.ylabel('Frecuencia')
plt.grid(True)

plt.subplot(1, 2, 2)
sns.boxplot(x='default payment next month', y='PAY_6', data=data_df)
plt.xlabel('default payment next month')
plt.ylabel('Estado de Pago en el Sexto Mes Anterior (PAY_6)')
plt.title('Diagrama de Caja de la variable "PAY_6" con respecto a la variable de respuesta')
plt.grid(True)

plt.show()

# Calcular el porcentaje de valores atípicos en PAY_6
Q1, Q3 = data_df['PAY_6'].quantile([0.25, 0.75])
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers_percentage = ((data_df['PAY_6'] < lower_bound) | (data_df['PAY_6'] > upper_bound)).mean() * 100

print("Porcentaje de valores atípicos en PAY_6:", outliers_percentage, "%")
# Out:
# count    30000.000000
# mean        -0.291100
# std          1.149988
# min         -2.000000
# 25%         -1.000000
# 50%          0.000000
# 75%          0.000000
# max          8.000000
# Name: PAY_6, dtype: float64
# Porcentaje de valores atípicos en PAY_6: 10.263333333333332 %

# %% [markdown]
# BILL

# %%
# Iterar sobre las variables 'BILL_AMT1' a 'BILL_AMT6'
bill_amt_vars = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
for bill_amt_var in bill_amt_vars:
    # Descripción de la variable
    bill_amt_description = data_df[bill_amt_var].describe()
    print(bill_amt_description)

    # Histograma y Boxplot de la variable
    plt.figure(figsize=(16, 6))

    plt.subplot(1, 2, 1)
    plt.hist(data_df[bill_amt_var], color='skyblue', edgecolor='black')
    plt.title(f'Histograma de la variable "{bill_amt_var}"')
    plt.xlabel(f'{bill_amt_var}')
    plt.ylabel('Frecuencia')
    plt.grid(True)

    plt.subplot(1, 2, 2)
    sns.boxplot(x='default payment next month', y=bill_amt_var, data=data_df)
    plt.xlabel('default payment next month')
    plt.ylabel(f'{bill_amt_var}')
    plt.title(f'Diagrama de Caja de la variable "{bill_amt_var}" con respecto a la variable de respuesta')
    plt.grid(True)

    plt.show()

    # Calcular el porcentaje de valores atípicos
    Q1, Q3 = data_df[bill_amt_var].quantile([0.25, 0.75])
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers_percentage = ((data_df[bill_amt_var] < lower_bound) | (data_df[bill_amt_var] > upper_bound)).mean() * 100

    print(f"Porcentaje de valores atípicos en {bill_amt_var}:", outliers_percentage, "%")
# Out:
# count     30000.000000
# mean      51223.330900
# std       73635.860576
# min     -165580.000000
# 25%        3558.750000
# 50%       22381.500000
# 75%       67091.000000
# max      964511.000000
# Name: BILL_AMT1, dtype: float64
# Porcentaje de valores atípicos en BILL_AMT1: 8.0 %
# count     30000.000000
# mean      49179.075167
# std       71173.768783
# min      -69777.000000
# 25%        2984.750000
# 50%       21200.000000
# 75%       64006.250000
# max      983931.000000
# Name: BILL_AMT2, dtype: float64
# Porcentaje de valores atípicos en BILL_AMT2: 7.983333333333334 %
# count    3.000000e+04
# mean     4.701315e+04
# std      6.934939e+04
# min     -1.572640e+05
# 25%      2.666250e+03
# 50%      2.008850e+04
# 75%      6.016475e+04
# max      1.664089e+06
# Name: BILL_AMT3, dtype: float64
# Porcentaje de valores atípicos en BILL_AMT3: 8.23 %
# count     30000.000000
# mean      43262.948967
# std       64332.856134
# min     -170000.000000
# 25%        2326.750000
# ...

# %%
# Crear subplots
plt.figure(figsize=(18, 6))
for i in range(1, 7):
    plt.subplot(2, 3, i)
    sns.boxplot(x='default payment next month', y='BILL_AMT{}'.format(i), data=data_df)
    plt.xlabel('default payment next month')
    plt.ylabel('BILL_AMT{}'.format(i))
    plt.title('Diagrama de Caja de BILL_AMT{} con respecto a la variable de respuesta'.format(i))
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Pay AMT

# %%
# Iterar sobre las variables 'PAY_AMT1' a 'PAY_AMT6'
pay_amt_vars = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
for pay_amt_var in pay_amt_vars:
    # Descripción de la variable
    pay_amt_description = data_df[pay_amt_var].describe()
    print(pay_amt_description)

    # Histograma y Boxplot de la variable
    plt.figure(figsize=(16, 6))

    plt.subplot(1, 2, 1)
    plt.hist(data_df[pay_amt_var], color='skyblue', edgecolor='black')
    plt.title(f'Histograma de la variable "{pay_amt_var}"')
    plt.xlabel(f'{pay_amt_var}')
    plt.ylabel('Frecuencia')
    plt.grid(True)

    plt.subplot(1, 2, 2)
    sns.boxplot(x='default payment next month', y=pay_amt_var, data=data_df)
    plt.xlabel('default payment next month')
    plt.ylabel(f'{pay_amt_var}')
    plt.title(f'Diagrama de Caja de la variable "{pay_amt_var}" con respecto a la variable de respuesta')
    plt.grid(True)

    plt.show()

    # Calcular el porcentaje de valores atípicos
    Q1, Q3 = data_df[pay_amt_var].quantile([0.25, 0.75])
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers_percentage = ((data_df[pay_amt_var] < lower_bound) | (data_df[pay_amt_var] > upper_bound)).mean() * 100

    print(f"Porcentaje de valores atípicos en {pay_amt_var}:", outliers_percentage, "%")
# Out:
# count     30000.000000
# mean       5663.580500
# std       16563.280354
# min           0.000000
# 25%        1000.000000
# 50%        2100.000000
# 75%        5006.000000
# max      873552.000000
# Name: PAY_AMT1, dtype: float64
# Porcentaje de valores atípicos en PAY_AMT1: 9.15 %
# count    3.000000e+04
# mean     5.921163e+03
# std      2.304087e+04
# min      0.000000e+00
# 25%      8.330000e+02
# 50%      2.009000e+03
# 75%      5.000000e+03
# max      1.684259e+06
# Name: PAY_AMT2, dtype: float64
# Porcentaje de valores atípicos en PAY_AMT2: 9.046666666666667 %
# count     30000.00000
# mean       5225.68150
# std       17606.96147
# min           0.00000
# 25%         390.00000
# 50%        1800.00000
# 75%        4505.00000
# max      896040.00000
# Name: PAY_AMT3, dtype: float64
# Porcentaje de valores atípicos en PAY_AMT3: 8.66 %
# count     30000.000000
# mean       4826.076867
# std       15666.159744
# min           0.000000
# 25%         296.000000
# ...

# %%
# Crear subplots
plt.figure(figsize=(18, 6))
for i in range(1, 7):
    plt.subplot(2, 3, i)
    sns.boxplot(x='default payment next month', y='PAY_AMT{}'.format(i), data=data_df)
    plt.xlabel('default payment next month')
    plt.ylabel('PAY_AMT{}'.format(i))
    plt.title('Diagrama de Caja de PAY_AMT{} con respecto a la variable de respuesta'.format(i))
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Valores atipicos
# #Juan fer dijo que arriba de 5% tocaba hacer algo

# %%
outliers_percentage_dict = {}

for column in data_df.columns:
    # Calcular los cuartiles Q1 y Q3
    Q1, Q3 = data_df[column].quantile([0.25, 0.75])
    
    # Calcular el rango intercuartil (IQR)
    IQR = Q3 - Q1
    
    # Calcular los límites para los valores atípicos
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Contar el número de valores atípicos
    outliers_count = ((data_df[column] < lower_bound) | (data_df[column] > upper_bound)).sum()
    
    # Calcular el porcentaje de valores atípicos
    outliers_percentage = outliers_count / len(data_df[column]) * 100
    
    # Guardar el porcentaje de valores atípicos en un diccionario
    outliers_percentage_dict[column] = outliers_percentage

# Imprimir el porcentaje de valores atípicos para cada variable
print("Porcentaje de valores atípicos para cada variable:")
for column, percentage in outliers_percentage_dict.items():
    print(column, ":", percentage, "%")
# Out:
# Porcentaje de valores atípicos para cada variable:
# ID : 0.0 %
# LIMIT_BAL : 0.5566666666666666 %
# SEX : 0.0 %
# EDUCATION : 1.5133333333333334 %
# MARRIAGE : 0.0 %
# AGE : 0.9066666666666667 %
# PAY_0 : 10.433333333333334 %
# PAY_2 : 14.7 %
# PAY_3 : 14.030000000000001 %
# PAY_4 : 11.693333333333333 %
# PAY_5 : 9.893333333333333 %
# PAY_6 : 10.263333333333332 %
# BILL_AMT1 : 8.0 %
# BILL_AMT2 : 7.983333333333334 %
# BILL_AMT3 : 8.23 %
# BILL_AMT4 : 8.74 %
# BILL_AMT5 : 9.083333333333334 %
# BILL_AMT6 : 8.976666666666667 %
# PAY_AMT1 : 9.15 %
# PAY_AMT2 : 9.046666666666667 %
# PAY_AMT3 : 8.66 %
# PAY_AMT4 : 9.98 %
# PAY_AMT5 : 9.816666666666666 %
# PAY_AMT6 : 9.86 %
# default payment next month : 22.12 %
