# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Provide the correct file path to the Excel file using raw string literal (r prefix)
path = r"C:\Users\juani\Desktop\analitica1\Proyecto\Proyecto2\data.xls"

# Read the Excel file
data_df = pd.read_excel(path)

# Display the first few rows of the DataFrame
data_df.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
#         X21       X22       X23                           Y
# 0  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1         0         0         0                           1
# 2      1000         0      2000                           1
# 3      1000      1000      5000                           0
# 4      1100      1069      1000                           0
#
# [5 rows x 25 columns]

# %%
column_names = ["ID", "LIMIT_BAL", "SEX", "EDUCATION", "MARRIAGE", "AGE", "PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6", "BILL_AMT1", "BILL_AMT2", "BILL_AMT3", "BILL_AMT4", "BILL_AMT5", "BILL_AMT6", "PAY_AMT1", "PAY_AMT2", "PAY_AMT3", "PAY_AMT4", "PAY_AMT5", "PAY_AMT6", "default payment next month"]

# Asignar los nombres de las columnas al DataFrame
data_df.columns = column_names

# Mostrar las primeras filas del DataFrame
data_df.head()

# Quitar la primera fila del DataFrame
data_df = data_df.drop(index=0)

# Mostrar las primeras filas del DataFrame actualizado
data_df.head()
# Out:
#   ID LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4  ...  \
# 1  1     20000   2         2        1  24     2     2    -1    -1  ...
# 2  2    120000   2         2        2  26    -1     2     0     0  ...
# 3  3     90000   2         2        2  34     0     0     0     0  ...
# 4  4     50000   2         2        1  37     0     0     0     0  ...
# 5  5     50000   1         2        1  57    -1     0    -1     0  ...
#
#   BILL_AMT4 BILL_AMT5 BILL_AMT6 PAY_AMT1 PAY_AMT2 PAY_AMT3 PAY_AMT4 PAY_AMT5  \
# 1         0         0         0        0      689        0        0        0
# 2      3272      3455      3261        0     1000     1000     1000        0
# 3     14331     14948     15549     1518     1500     1000     1000     1000
# 4     28314     28959     29547     2000     2019     1200     1100     1069
# 5     20940     19146     19131     2000    36681    10000     9000      689
#
#   PAY_AMT6 default payment next month
# 1        0                          1
# 2     2000                          1
# 3     5000                          0
# 4     1000                          0
# 5      679                          0
#
# [5 rows x 25 columns]

# %%
data_df.dtypes
# Out:
# ID                            object
# LIMIT_BAL                     object
# SEX                           object
# EDUCATION                     object
# MARRIAGE                      object
# AGE                           object
# PAY_0                         object
# PAY_2                         object
# PAY_3                         object
# PAY_4                         object
# PAY_5                         object
# PAY_6                         object
# BILL_AMT1                     object
# BILL_AMT2                     object
# BILL_AMT3                     object
# BILL_AMT4                     object
# BILL_AMT5                     object
# BILL_AMT6                     object
# PAY_AMT1                      object
# PAY_AMT2                      object
# PAY_AMT3                      object
# PAY_AMT4                      object
# PAY_AMT5                      object
# PAY_AMT6                      object
# default payment next month    object
# dtype: object

# %%
data_df = data_df.apply(pd.to_numeric, errors='coerce')

# Mostrar los tipos de datos después de la conversión
print(data_df.dtypes)
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
#Análisis de completitud
(data_df.isnull().sum() / data_df.shape[0]).sort_values(ascending = False)
# Out:
# ID                            0.0
# BILL_AMT2                     0.0
# PAY_AMT6                      0.0
# PAY_AMT5                      0.0
# PAY_AMT4                      0.0
# PAY_AMT3                      0.0
# PAY_AMT2                      0.0
# PAY_AMT1                      0.0
# BILL_AMT6                     0.0
# BILL_AMT5                     0.0
# BILL_AMT4                     0.0
# BILL_AMT3                     0.0
# BILL_AMT1                     0.0
# LIMIT_BAL                     0.0
# PAY_6                         0.0
# PAY_5                         0.0
# PAY_4                         0.0
# PAY_3                         0.0
# PAY_2                         0.0
# PAY_0                         0.0
# AGE                           0.0
# MARRIAGE                      0.0
# EDUCATION                     0.0
# SEX                           0.0
# default payment next month    0.0
# dtype: float64

# %%
# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Gráfico de violín
sns.violinplot(x="SEX", data=data_df, ax=ax1)
ax1.set_xlabel("Sexo")
ax1.set_ylabel("Distribución")
ax1.set_title("Distribución de la variable SEX")

# Gráfico de conteo
sns.countplot(x="SEX", data=data_df, ax=ax2)
ax2.set_xlabel("Sexo")
ax2.set_ylabel("Cantidad de datos")
ax2.set_title("Cantidad de datos por sexo")

# Ajustar el diseño
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %%
# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Gráfico de violín
sns.violinplot(x="EDUCATION", data=data_df, ax=ax1)
ax1.set_xlabel("Educación")
ax1.set_ylabel("Distribución")
ax1.set_title("Distribución de la variable EDUCATION")

# Gráfico de conteo
sns.countplot(x="EDUCATION", data=data_df, ax=ax2)
ax2.set_xlabel("Educación")
ax2.set_ylabel("Cantidad de datos")
ax2.set_title("Cantidad de datos por nivel de educación")

# Ajustar el diseño
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %%
# Crear una figura con dos subgráficos
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Gráfico de violín
sns.violinplot(x="MARRIAGE", data=data_df, ax=ax1)
ax1.set_xlabel("Matrimonio")
ax1.set_ylabel("Distribución")
ax1.set_title("Distribución de la variable MARRIAGE")

# Gráfico de conteo
sns.countplot(x="MARRIAGE", data=data_df, ax=ax2)
ax2.set_xlabel("Matrimonio")
ax2.set_ylabel("Cantidad de datos")
ax2.set_title("Cantidad de datos por estado civil")

# Ajustar el diseño
plt.tight_layout()

# Mostrar los gráficos
plt.show()

# %%
# Copiar el DataFrame original data_df
data_df_modeling = data_df.copy()

# Obtener variables categóricas
variables_categoricas = ['MARRIAGE', 'EDUCATION', 'SEX']

# Convertir variables categóricas en variables dummy y agregarlas al DataFrame copiado
for variable in variables_categoricas:
    dummies = pd.get_dummies(data_df_modeling[variable], prefix=variable, drop_first=True)
    data_df_modeling = pd.concat([data_df_modeling, dummies], axis=1)
    data_df_modeling.drop(variable, axis=1, inplace=True)

# Ver las primeras filas del DataFrame copiado con las variables dummy
data_df_modeling.head()
# Out:
#    ID  LIMIT_BAL  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
# 1   1      20000   24      2      2     -1     -1     -2     -2       3913
# 2   2     120000   26     -1      2      0      0      0      2       2682
# 3   3      90000   34      0      0      0      0      0      0      29239
# 4   4      50000   37      0      0      0      0      0      0      46990
# 5   5      50000   57     -1      0     -1      0      0      0       8617
#
#    ...  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3  EDUCATION_1  EDUCATION_2  \
# 1  ...        True       False       False        False         True
# 2  ...       False        True       False        False         True
# 3  ...       False        True       False        False         True
# 4  ...        True       False       False        False         True
# 5  ...        True       False       False        False         True
#
#    EDUCATION_3  EDUCATION_4  EDUCATION_5  EDUCATION_6  SEX_2
# 1        False        False        False        False   True
# 2        False        False        False        False   True
# 3        False        False        False        False   True
# 4        False        False        False        False   True
# 5        False        False        False        False  False
#
# [5 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Definir las características numéricas
features_numericas = ["AGE", "PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6", "BILL_AMT1", "BILL_AMT2", "BILL_AMT3", "BILL_AMT4", "BILL_AMT5", "BILL_AMT6", "PAY_AMT1", "PAY_AMT2", "PAY_AMT3", "PAY_AMT4", "PAY_AMT5", "PAY_AMT6", "default payment next month"]

# Calcular la matriz de correlación
correlation_matrix = data_df_modeling[features_numericas].corr()

# Crear el gráfico de heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap='vlag', annot=True, fmt=".2f", vmin=-1, vmax=1)
plt.title('Matriz de correlación entre características numéricas')
plt.show()

# %%
data_df_modeling.to_csv('clean_data.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data_df_modeling.to_csv('clean_data.txt')
#
# NameError: name 'data_df_modeling' is not defined

# %%
# Descripción de la variable 'PAY_0'
pay_0_description = data_df['PAY_0'].describe()
print(pay_0_description)

# Histograma de la variable 'PAY_0'
plt.figure(figsize=(8, 6))
plt.hist(data_df['PAY_0'], color='skyblue', edgecolor='black')
plt.title('Histograma de la variable "PAY_0"')
plt.xlabel('Estado de Pago en el Mes Anterior (PAY_0)')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# Boxplot de la variable 'PAY_0'
plt.figure(figsize=(8, 6))
plt.boxplot(data_df['PAY_0'])
plt.title('Diagrama de Caja de la variable "PAY_0"')
plt.ylabel('Estado de Pago en el Mes Anterior (PAY_0)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Descripción de la variable 'PAY_0'
# ----> 2 pay_0_description = data_df['PAY_0'].describe()
#       3 print(pay_0_description)
#       5 # Histograma de la variable 'PAY_0'
#
# NameError: name 'data_df' is not defined
